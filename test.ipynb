# %%
import os
os.environ["LD_LIBRARY_PATH"] = "/cvmfs/hpc.rug.nl/versions/2023.01/rocky8/x86_64/amd/zen3/software/imkl/2025.1.0/mkl/2025.1/lib/:/cvmfs/hpc.rug.nl/versions/2023.01/rocky8/x86_64/amd/zen3/software/FFTW/3.3.10-GCC-12.2.0/lib/"
import ctypes
ctypes.CDLL("/cvmfs/hpc.rug.nl/versions/2023.01/rocky8/x86_64/amd/zen3/software/imkl/2025.1.0/mkl/2025.1/lib/libmkl_rt.so")
ctypes.CDLL("/cvmfs/hpc.rug.nl/versions/2023.01/rocky8/x86_64/amd/zen3/software/FFTW/3.3.10-GCC-12.2.0/lib/libfftw3f.so.3")
# Out:
# <CDLL '/cvmfs/hpc.rug.nl/versions/2023.01/rocky8/x86_64/amd/zen3/software/FFTW/3.3.10-GCC-12.2.0/lib/libfftw3f.so.3', handle 30e7b00 at 0x7f7598167dd0>
